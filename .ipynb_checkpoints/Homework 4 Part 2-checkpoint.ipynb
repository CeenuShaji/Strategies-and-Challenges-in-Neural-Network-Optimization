# %% [markdown]
# # Homework 4 Part 2 - Solutions

# %% [markdown]
# **<font color='blue'>In order to solve this assignment, you must work with a TensorFlow kernel in HiPerGator. If you are working locally, you must [install TensorFlow 2](https://www.tensorflow.org/install).</font>**

# %% [markdown]
# # Problem 1 (25 points)
#
# In this problem you will be experimenting with a special MLP architecture, known as _autoencoder_ (or AE).
#
# An autoencoder attempts to find efficient latent representations of the inputs, it then spits out something that (hopefully) looks very close to the inputs. An autoencoder is always composed of two parts:
#
# 1. an encoder (or recognition network) that converts the inputs to a latent representation, followed by
# 2. a decoder (or generative network) that converts the internal representation to the outputs.

# %%
from IPython.display import Image
Image('figures/autoencoder.png', width=400)

# %% [markdown]
# As you can see, an autoencoder typically has the same architecture as a Multi-Layer Perceptron (MLP), except that the number of neurons in the output layer must be equal to the number of inputs. In this example, there is just one hidden layer composed of two neurons (the encoder), and one output layer composed of three neurons (the decoder). The outputs are often called the
# reconstructions because the autoencoder tries to reconstruct the inputs, and the cost function contains a reconstruction loss that penalizes the model when the reconstructions are different from the inputs.
#
# Because the internal representation has a lower dimensionality than the input data (it is 2D instead of 3D), the autoencoder is said to be undercomplete. An undercomplete autoencoder cannot trivially copy its inputs to the codings, yet it must find a way to output a copy of its inputs. It is forced to learn the most important features in the input data (and drop the unimportant ones).
#
# Just like other neural networks we have discussed, autoencoders can have multiple hidden layers. In this case they are called stacked autoencoders (or deep autoencoders). Adding more layers helps the autoencoder learn more complex codings.
#
# The architecture of a stacked autoencoder is typically symmetrical with regard to the central hidden layer (the coding layer). For example, an autoencoder for the MNIST may have 784 inputs, followed by a hidden layer with 100 neurons, then a central hidden layer of 30 neurons, then another hidden layer with 100 neurons, and an output layer with 784 neurons:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
import tensorflow as tf
from tensorflow import keras
from time import time
import warnings
warnings.filterwarnings('ignore')

# %%
mnist = keras.datasets.mnist

(X_train_full, t_train_full), (X_test, t_test) = mnist.load_data()

X_train_full.shape, t_train_full.shape, X_test.shape, t_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
# Training and Validation sets
# First 5,000 samples as validation and the remaining ones as training samples
X_valid, X_train = X_train_full[:5000] / 255.0, X_train_full[5000:] / 255.0
t_valid, t_train = t_train_full[:5000], t_train_full[5000:]
X_test = X_test / 255.0

# %%
plt.figure(figsize=(10,5))
plot_idx=1
for i in range(10):
    labels = np.where(t_train==i)[0]
    idx = np.random.permutation(range(len(labels)))
    for j in range(1,16):
        plt.subplot(10,15,plot_idx)
        plt.imshow(X_train[labels[j],:,:], cmap='binary')
        plt.axis('off')
        plot_idx+=1

# %%
# Reproducible results - fix the random seed generator (doesn't account for GPU-induced randomness)
tf.random.set_seed(2)

# Stacked Auto-Encoder
def stacked_autoencoder(X_train, X_valid, embedding_size=30, input_shape=[28,28], epochs=10):
    stacked_encoder = keras.models.Sequential([
        keras.layers.Flatten(input_shape=input_shape),
        keras.layers.Dense(100, activation='relu'),
        keras.layers.Dense(embedding_size, activation='relu')])

    stacked_decoder = keras.models.Sequential([
        keras.layers.Dense(100, activation='relu', input_shape=[embedding_size]),
        keras.layers.Dense(input_shape[0] * input_shape[1], activation='sigmoid'),
        keras.layers.Reshape(input_shape)])

    stacked_ae = keras.models.Sequential([stacked_encoder, stacked_decoder])

    stacked_ae.compile(loss=keras.losses.BinaryCrossentropy(),
                       optimizer=keras.optimizers.Adam(),
                      )

    start = time()
    history = stacked_ae.fit(X_train, X_train, epochs=epochs, batch_size=32,
                             validation_data=[X_valid, X_valid])
    print('Elapsed Time: ',time()-start, ' seconds')
    
    return stacked_ae


# Embedding dimensionality
embedding_size = 30

# Training Stacked Autoencoder
stacked_ae = stacked_autoencoder(X_train, X_valid, embedding_size)
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 16s 8ms/step - loss: 0.1486 - val_loss: 0.1118
# Epoch 2/10
# 1719/1719 [==============================] - 12s 7ms/step - loss: 0.1057 - val_loss: 0.1009
# Epoch 3/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0984 - val_loss: 0.0964
# Epoch 4/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0953 - val_loss: 0.0938
# Epoch 5/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0933 - val_loss: 0.0926
# Epoch 6/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0919 - val_loss: 0.0911
# Epoch 7/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0907 - val_loss: 0.0902
# Epoch 8/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0898 - val_loss: 0.0896
# Epoch 9/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0890 - val_loss: 0.0888
# Epoch 10/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.0884 - val_loss: 0.0878
# Elapsed Time:  136.65750885009766  seconds

# %% [markdown]
# When compiling the stacked autoencoder, we use the binary cross-entropy loss instead of the mean squared error. We are treating the reconstruction task as a multilabel binary classification problem: each pixel intensity represents the probability that the pixel should be black. Framing it this way (rather than as a regression problem) tends to make the model converge faster.

# %% [markdown]
# Let's visualize some example reconstructions:

# %%
def plot_image(image):
    plt.imshow(image, cmap='binary')
    plt.axis('off')

def show_reconstructions(model, X_valid=X_valid, input_shape=[28,28], compute_error=True, n_images=30):
    reconstructions = model.predict(X_valid[:n_images])
    if compute_error:
        error=X_valid[:n_images]-reconstructions
        avg_MSE=np.mean(np.mean(error.reshape((n_images,input_shape[0]*input_shape[1]))**2,axis=1))
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(X_valid[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])
    if compute_error:
        print('Average MSE of reconstruction: ', avg_MSE)

# %%
# Show Reconstructions

show_reconstructions(stacked_ae)
# Out:
# 1/1 [==============================] - 0s 230ms/step
# Average MSE of reconstruction:  0.008197180673294108

# %% [markdown]
# ### Accessing Outputs at the Bottleneck Layer
#
# To demonstrate this, let's consider a stacked autoencoder with a 2-dimensional bottleneck layer (embedding dimension):

# %%
# Embedding dimensionality
embedding_size = 2

# Training Stacked Autoencoder
stacked_ae = stacked_autoencoder(X_train, X_valid, embedding_size)

# Show Reconstructions
show_reconstructions(stacked_ae)
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 15s 8ms/step - loss: 0.2334 - val_loss: 0.2123
# Epoch 2/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.2097 - val_loss: 0.2057
# Epoch 3/10
# 1719/1719 [==============================] - 13s 8ms/step - loss: 0.2048 - val_loss: 0.2013
# Epoch 4/10
# 1719/1719 [==============================] - 13s 7ms/step - loss: 0.2006 - val_loss: 0.1974
# Epoch 5/10
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.1977 - val_loss: 0.1948
# Epoch 6/10
# 1719/1719 [==============================] - 15s 9ms/step - loss: 0.1957 - val_loss: 0.1933
# Epoch 7/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.1943 - val_loss: 0.1921
# Epoch 8/10
# 1719/1719 [==============================] - 15s 8ms/step - loss: 0.1932 - val_loss: 0.1908
# Epoch 9/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.1921 - val_loss: 0.1899
# Epoch 10/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.1911 - val_loss: 0.1892
# Elapsed Time:  135.40046191215515  seconds
# 1/1 [==============================] - 0s 142ms/step
# Average MSE of reconstruction:  0.03935733655953293

# %% [markdown]
# If you want to access the embedding output produced at the bottleneck layer, you can do the following:

# %%
stacked_ae.layers

# The "1st layer" corresponds ot the stacked encoder
# The "2nd layer" corresponds ot the stacked decoder
# Out:
# [<keras.engine.sequential.Sequential at 0x29e6fbe05b0>,
#  <keras.engine.sequential.Sequential at 0x29e6fc04f40>]

# %%
enc = stacked_ae.layers[0]
enc.layers

# As you can see, the stacked encoder contains a reshaping layer (flatten), 1st hidden layer and the bottleneck layer.
# Let's obtain the output at each layer and pass it to the next
# Out:
# [<keras.layers.reshaping.flatten.Flatten at 0x29e6fbbe100>,
#  <keras.layers.core.dense.Dense at 0x29e6fbbe160>,
#  <keras.layers.core.dense.Dense at 0x29e6fbbe820>]

# %%
flatten = enc.layers[0](X_train)
hidden1 = enc.layers[1](flatten)
bottleneck = enc.layers[2](hidden1)

# %%
bottleneck.shape
# Out:
# TensorShape([55000, 2])

# %% [markdown]
# As expected, the bottleneck layer mapped all 55,000 training images to a 2-dimensional space. Since its 2-D, we can visualize it:

# %%
plt.scatter(bottleneck[:,0], bottleneck[:,1], c=t_train)
plt.colorbar();

# %% [markdown]
# Answer the following questions:
#
# 1. (7 points) Experiment with different embedding dimensions (at least 3 values). At least a "very small" embedding space (like 2), "very large" embedding space (like 90), and another in between. Discuss your observations regarding the speed of training, quality of reconstruction images, and the reconstruction average MSE.

# %% [markdown]
# For space 2:
# Speed=Slow
# Quality=Not much
# MSE=0.03

# %%
# Embedding dimensionality
embedding_size = 30

# Training Stacked Autoencoder
stacked_ae = stacked_autoencoder(X_train, X_valid, embedding_size)

# Show Reconstructions
show_reconstructions(stacked_ae)

stacked_ae.layers

enc = stacked_ae.layers[0]
enc.layers

flatten = enc.layers[0](X_train)
hidden1 = enc.layers[1](flatten)
bottleneck = enc.layers[2](hidden1)

bottleneck.shape

plt.scatter(bottleneck[:,0], bottleneck[:,1], c=t_train)
plt.colorbar();
# Out:
# Epoch 1/10
# 1719/1719 [==============================] - 17s 9ms/step - loss: 0.1467 - val_loss: 0.1097
# Epoch 2/10
# 1719/1719 [==============================] - 15s 9ms/step - loss: 0.1043 - val_loss: 0.1000
# Epoch 3/10
# 1719/1719 [==============================] - 15s 9ms/step - loss: 0.0985 - val_loss: 0.0964
# Epoch 4/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0957 - val_loss: 0.0945
# Epoch 5/10
# 1719/1719 [==============================] - 15s 8ms/step - loss: 0.0938 - val_loss: 0.0931
# Epoch 6/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0924 - val_loss: 0.0921
# Epoch 7/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0914 - val_loss: 0.0915
# Epoch 8/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0907 - val_loss: 0.0906
# Epoch 9/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0900 - val_loss: 0.0899
# Epoch 10/10
# 1719/1719 [==============================] - 14s 8ms/step - loss: 0.0895 - val_loss: 0.0894
# Elapsed Time:  145.73549509048462  seconds
# 1/1 [==============================] - 0s 162ms/step
# Average MSE of reconstruction:  0.008703274181070178

# %% [markdown]
# For space 50:
# Speed=Faster than earlier
# Quality=Better
# MSE=0.008

# %%
# Embedding dimensionality
embedding_size = 90

# Training Stacked Autoencoder
stacked_ae = stacked_autoencoder(X_train, X_valid, embedding_size)

# Show Reconstructions
show_reconstructions(stacked_ae)

stacked_ae.layers

enc = stacked_ae.layers[0]
enc.layers

flatten = enc.layers[0](X_train)
hidden1 = enc.layers[1](flatten)
bottleneck = enc.layers[2](hidden1)

bottleneck.shape

plt.scatter(bottleneck[:,0], bottleneck[:,1], c=t_train)
plt.colorbar();
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 5>()
#       2 embedding_size = 90
#       4 # Training Stacked Autoencoder
# ----> 5 stacked_ae = stacked_autoencoder(X_train, X_valid, embedding_size)
#       7 # Show Reconstructions
#       8 show_reconstructions(stacked_ae)
#
# Input In [6], in stacked_autoencoder(X_train, X_valid, embedding_size, input_shape, epochs)
#      18 stacked_ae.compile(loss=keras.losses.BinaryCrossentropy(),
#      19                    optimizer=keras.optimizers.Adam(),
#      20                   )
#      22 start = time()
# ---> 23 history = stacked_ae.fit(X_train, X_train, epochs=epochs, batch_size=32,
#      24                          validation_data=[X_valid, X_valid])
#      25 print('Elapsed Time: ',time()-start, ' seconds')
#      27 return stacked_ae
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_filegq1uwq3p.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\ceenu\anaconda3\lib\site-packages\keras\engine\training.py", line 1249, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\ceenu\anaconda3\lib\site-packages\keras\engine\training.py", line 1233, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\ceenu\anaconda3\lib\site-packages\keras\engine\training.py", line 1222, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\ceenu\anaconda3\lib\site-packages\keras\engine\training.py", line 1023, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\ceenu\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\ceenu\anaconda3\lib\site-packages\keras\engine\input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_11" is incompatible with the layer: expected shape=(None, 28, 28), found shape=(None, 90000)

# %%
For space 90:
Speed=Fastest
Quality=Better

# %% [markdown]
# 2. (11 points) Compare the stacked AE reconstructions with those produced with PCA (for the same embedding dimensionality). Discuss your observations based on reconstruction visualization and average MSE.

# %% [markdown]
# PCA is cheaper in time and faster than AE. AE can overfit easily.
# By stacking several non-linear layers, neural networks such as autoencoders may flatten high-dimensional data into a low-dimensional latent space. Their input is accurately reconstructed since they are trained with back propagation. Autoencoders can be used for dimensionality reduction if the latent space is less than the input.
# PCA being linear is like an AE with one layer

# %% [markdown]
# 3. (7 points) For what autoencoder design (architecture, activation functions and objective function), will an autoencoder be producing the same results as PCA? Justify your answer.

# %% [markdown]
# Same results are produced only if bottleneck is smaller than input units.

# %% [markdown]
# That kind of a PCA can have a linear encoder with one hidden layer and square loss function with standardized inputs

# %% [markdown]
# ___

# %% [markdown]
# # Problem 2 (7.5 points)
#
# For this problem, consider the final project training data. Feel free to discuss with your team, but this is an individual assignment.

# %%
X_train = np.load('data_train.npy').T #I had to remove this file from my submission since it wont push, but I have attached the corrected labels
t_train_full = np.load('t_train_corrected.npy') # or np.load('t_train_corrected.npy')

# %% [markdown]
# You can convert ```numpy``` arrays to ```tensorflow``` tensors with:

# %%
X_train_full = tf.constant(X_train.reshape(X_train.shape[0], 300, 300))

X_train_full.shape
# Out:
# TensorShape([9032, 300, 300])

# %% [markdown]
# Answer the following questions:
#
# 1. (1 point) Split your data into training and validation sets. Use a stratified 80/20 partition with a fixed ```random_state``` (in order to avoid data leakage).

# %%
# Training and Validation sets
print(X_train.shape)

X_valid, X_train = X_train_full[:7225] / 255.0, X_train_full[1806:] / 255.0
t_valid, t_train = t_train_full[:7225], t_train_full[1806:]
X_test = X_test / 255.0
# Out:
# (9032, 90000)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 4>()
#       1 # Training and Validation sets
#       2 print(X_train.shape)
# ----> 4 X_valid, X_train = X_train_full[:7225] / 255.0, X_train_full[1806:] / 255.0
#       5 t_valid, t_train = t_train_full[:7225], t_train_full[1806:]
#       6 X_test = X_test / 255.0
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:1517, in _truediv_python3(x, y, name)
#    1515 y_dtype = y.dtype.base_dtype
#    1516 if x_dtype != y_dtype:
# -> 1517   raise TypeError(f"`x` and `y` must have the same dtype, "
#    1518                   f"got {x_dtype!r} != {y_dtype!r}.")
#    1519 try:
#    1520   dtype = _TRUEDIV_TABLE[x_dtype]
#
# TypeError: `x` and `y` must have the same dtype, got tf.uint8 != tf.float32.

# %% [markdown]
# 2. (3.5 points) Train a stacked autoencoder with an embedding dimension of at least 100-dimensional.

# %%
# Reproducible results - fix the random seed generator (doesn't account for GPU-induced randomness)
tf.random.set_seed(2)

# Stacked Auto-Encoder
def stacked_autoencoder(X_train, X_valid, embedding_size=30, input_shape=[9039,9039], epochs=10):
    stacked_encoder = keras.models.Sequential([
        keras.layers.Flatten(input_shape=input_shape),
        keras.layers.Dense(100, activation='relu'),
        keras.layers.Dense(embedding_size, activation='relu')])

    stacked_decoder = keras.models.Sequential([
        keras.layers.Dense(100, activation='relu', input_shape=[embedding_size]),
        keras.layers.Dense(input_shape[0] * input_shape[1], activation='sigmoid'),
        keras.layers.Reshape(input_shape)])

    stacked_ae = keras.models.Sequential([stacked_encoder, stacked_decoder])

    stacked_ae.compile(loss=keras.losses.BinaryCrossentropy(),
                       optimizer=keras.optimizers.Adam(),
                      )

    start = time()
    history = stacked_ae.fit(X_train, X_train, epochs=epochs, batch_size=32,
                             validation_data=[X_valid, X_valid])
    print('Elapsed Time: ',time()-start, ' seconds')
    
    return stacked_ae


# Embedding dimensionality
embedding_size = 100

# Training Stacked Autoencoder
stacked_ae = stacked_autoencoder(X_train, X_valid, embedding_size)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [23], in <cell line: 34>()
#      31 embedding_size = 100
#      33 # Training Stacked Autoencoder
# ---> 34 stacked_ae = stacked_autoencoder(X_train, X_valid, embedding_size)
#
# Input In [23], in stacked_autoencoder(X_train, X_valid, embedding_size, input_shape, epochs)
#       5 def stacked_autoencoder(X_train, X_valid, embedding_size=30, input_shape=[9039,9039], epochs=10):
# ----> 6     stacked_encoder = keras.models.Sequential([
#       7         keras.layers.Flatten(input_shape=input_shape),
#       8         keras.layers.Dense(100, activation='relu'),
#       9         keras.layers.Dense(embedding_size, activation='relu')])
#      11     stacked_decoder = keras.models.Sequential([
#      12         keras.layers.Dense(100, activation='relu', input_shape=[embedding_size]),
#      13         keras.layers.Dense(input_shape[0] * input_shape[1], activation='sigmoid'),
#      14         keras.layers.Reshape(input_shape)])
#      16     stacked_ae = keras.models.Sequential([stacked_encoder, stacked_decoder])
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\sequential.py:143, in Sequential.__init__(self, layers, name)
#     141     layers = [layers]
#     142 for layer in layers:
# --> 143     self.add(layer)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\sequential.py:237, in Sequential.add(self, layer)
#     232         self._has_explicit_input_shape = True
#     234 elif self.outputs:
#     235     # If the model is being built continuously on top of an input layer:
#     236     # refresh its output.
# --> 237     output_tensor = layer(self.outputs[0])
#     238     if len(tf.nest.flatten(output_tensor)) != 1:
#     239         raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:1045, in Layer.__call__(self, *args, **kwargs)
#    1037 # Functional Model construction mode is invoked when `Layer`s are called
#    1038 # on symbolic `KerasTensor`s, i.e.:
#    1039 # >> inputs = tf.keras.Input(10)
#    1040 # >> outputs = MyLayer()(inputs)  # Functional construction mode.
#    1041 # >> model = tf.keras.Model(inputs, outputs)
#    1042 if _in_functional_construction_mode(
#    1043     self, inputs, args, kwargs, input_list
#    1044 ):
# -> 1045     return self._functional_construction_call(
#    1046         inputs, args, kwargs, input_list
#    1047     )
#    1049 # Maintains info about the `Layer.call` stack.
#    1050 call_context = base_layer_utils.call_context()
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:2535, in Layer._functional_construction_call(self, inputs, args, kwargs, input_list)
#    2528         training_arg_passed_by_framework = True
#    2530 with call_context.enter(
#    2531     layer=self, inputs=inputs, build_graph=True, training=training_value
#    2532 ):
#    2533     # Check input assumptions set after layer building, e.g. input
#    2534     # shape.
# -> 2535     outputs = self._keras_tensor_symbolic_call(
#    2536         inputs, input_masks, args, kwargs
#    2537     )
#    2539     if outputs is None:
#    2540         raise ValueError(
#    2541             "A layer's `call` method should return a "
#    2542             "Tensor or a list of Tensors, not None "
#    2543             "(layer: " + self.name + ")."
#    2544         )
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:2382, in Layer._keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#    2378     return tf.nest.map_structure(
#    2379         keras_tensor.KerasTensor, output_signature
#    2380     )
#    2381 else:
# -> 2382     return self._infer_output_signature(
#    2383         inputs, args, kwargs, input_masks
#    2384     )
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:2439, in Layer._infer_output_signature(self, inputs, args, kwargs, input_masks)
#    2431 with backend.name_scope(self._name_scope()):
#    2432     with autocast_variable.enable_auto_cast_variables(
#    2433         self._compute_dtype_object
#    2434     ):
#    (...)
#    2437         # TODO(kaftan): do we maybe_build here, or have we already
#    2438         # done it?
# -> 2439         self._maybe_build(inputs)
#    2440         inputs = self._maybe_cast_inputs(inputs)
#    2441         outputs = call_fn(inputs, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:2986, in Layer._maybe_build(self, inputs)
#    2981 if not hasattr(self.build, "_is_default"):
#    2982     # Any setup work performed only once should happen in an
#    2983     # `init_scope` to avoid creating symbolic Tensors that will
#    2984     # later pollute any eager operations.
#    2985     with tf_utils.maybe_init_scope(self):
# -> 2986         self.build(input_shapes)
#    2987 # We must set also ensure that the layer is marked as built, and the
#    2988 # build shape is stored since user defined build functions may not
#    2989 # be calling `super.build()`
#    2990 Layer.build(self, input_shapes)
#
# File ~\anaconda3\lib\site-packages\keras\layers\core\dense.py:154, in Dense.build(self, input_shape)
#     148     raise ValueError(
#     149         "The last dimension of the inputs to a Dense layer "
#     150         "should be defined. Found None. "
#     151         f"Full input shape received: {input_shape}"
#     152     )
#     153 self.input_spec = InputSpec(min_ndim=2, axes={-1: last_dim})
# --> 154 self.kernel = self.add_weight(
#     155     "kernel",
#     156     shape=[last_dim, self.units],
#     157     initializer=self.kernel_initializer,
#     158     regularizer=self.kernel_regularizer,
#     159     constraint=self.kernel_constraint,
#     160     dtype=self.dtype,
#     161     trainable=True,
#     162 )
#     163 if self.use_bias:
#     164     self.bias = self.add_weight(
#     165         "bias",
#     166         shape=[
#    (...)
#     173         trainable=True,
#     174     )
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer.py:711, in Layer.add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, **kwargs)
#     708 if layout:
#     709     getter = functools.partial(getter, layout=layout)
# --> 711 variable = self._add_variable_with_custom_getter(
#     712     name=name,
#     713     shape=shape,
#     714     # TODO(allenl): a `make_variable` equivalent should be added as a
#     715     # `Trackable` method.
#     716     getter=getter,
#     717     # Manage errors in Layer rather than Trackable.
#     718     overwrite=True,
#     719     initializer=initializer,
#     720     dtype=dtype,
#     721     constraint=constraint,
#     722     trainable=trainable,
#     723     use_resource=use_resource,
#     724     collections=collections_arg,
#     725     synchronization=synchronization,
#     726     aggregation=aggregation,
#     727     caching_device=caching_device,
#     728 )
#     729 if regularizer is not None:
#     730     # TODO(fchollet): in the future, this should be handled at the
#     731     # level of variable creation, and weight regularization losses
#     732     # should be variable attributes.
#     733     name_in_scope = variable.name[: variable.name.find(":")]
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\trackable\base.py:489, in Trackable._add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     479   if (checkpoint_initializer is not None and
#     480       not (isinstance(initializer, CheckpointInitialValueCallable) and
#     481            (initializer.restore_uid > checkpoint_initializer.restore_uid))):
#    (...)
#     486     # then we'll catch that when we call _track_trackable. So this is
#     487     # "best effort" to set the initializer with the highest restore UID.
#     488     initializer = checkpoint_initializer
# --> 489 new_variable = getter(
#     490     name=name,
#     491     shape=shape,
#     492     dtype=dtype,
#     493     initializer=initializer,
#     494     **kwargs_for_getter)
#     496 # If we set an initializer and the variable processed it, tracking will not
#     497 # assign again. It will add this variable to our dependencies, and if there
#     498 # is a non-trivial restoration queued, it will handle that. This also
#     499 # handles slot variables.
#     500 if not overwrite or isinstance(new_variable, Trackable):
#
# File ~\anaconda3\lib\site-packages\keras\engine\base_layer_utils.py:134, in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner, layout)
#     127     use_resource = True
#     129 if layout is None:
#     130     # In theory, in `use_resource` is True and `collections` is empty
#     131     # (that is to say, in TF2), we can use tf.Variable.
#     132     # However, this breaks legacy (Estimator) checkpoints because
#     133     # it changes variable names. Remove this when V1 is fully deprecated.
# --> 134     return tf1.Variable(
#     135         initial_value=init_val,
#     136         name=name,
#     137         trainable=trainable,
#     138         caching_device=caching_device,
#     139         dtype=variable_dtype,
#     140         validate_shape=validate_shape,
#     141         constraint=constraint,
#     142         use_resource=use_resource,
#     143         collections=collections,
#     144         synchronization=synchronization,
#     145         aggregation=aggregation,
#     146         shape=variable_shape if variable_shape else None,
#     147     )
#     148 else:
#     149     return dtensor.DVariable(
#     150         initial_value=init_val,
#     151         name=name,
#    (...)
#     160         shape=variable_shape if variable_shape else None,
#     161     )
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py:269, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     266 @traceback_utils.filter_traceback
#     267 def __call__(cls, *args, **kwargs):
#     268   if cls is VariableV1:
# --> 269     return cls._variable_v1_call(*args, **kwargs)
#     270   elif cls is Variable:
#     271     return cls._variable_v2_call(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py:210, in VariableMetaclass._variable_v1_call(cls, initial_value, trainable, collections, validate_shape, caching_device, name, variable_def, dtype, expected_shape, import_scope, constraint, use_resource, synchronization, aggregation, shape)
#     208 if aggregation is None:
#     209   aggregation = VariableAggregation.NONE
# --> 210 return previous_getter(
#     211     initial_value=initial_value,
#     212     trainable=trainable,
#     213     collections=collections,
#     214     validate_shape=validate_shape,
#     215     caching_device=caching_device,
#     216     name=name,
#     217     variable_def=variable_def,
#     218     dtype=dtype,
#     219     expected_shape=expected_shape,
#     220     import_scope=import_scope,
#     221     constraint=constraint,
#     222     use_resource=use_resource,
#     223     synchronization=synchronization,
#     224     aggregation=aggregation,
#     225     shape=shape)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py:203, in VariableMetaclass._variable_v1_call.<locals>.<lambda>(**kwargs)
#     186 def _variable_v1_call(cls,
#     187                       initial_value=None,
#     188                       trainable=None,
#    (...)
#     200                       aggregation=VariableAggregation.NONE,
#     201                       shape=None):
#     202   """Call on Variable class. Useful to force the signature."""
# --> 203   previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     204   for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     205     previous_getter = _make_getter(getter, previous_getter)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py:2706, in default_variable_creator(next_creator, **kwargs)
#    2704 if use_resource:
#    2705   distribute_strategy = kwargs.get("distribute_strategy", None)
# -> 2706   return resource_variable_ops.ResourceVariable(
#    2707       initial_value=initial_value,
#    2708       trainable=trainable,
#    2709       collections=collections,
#    2710       validate_shape=validate_shape,
#    2711       caching_device=caching_device,
#    2712       name=name,
#    2713       dtype=dtype,
#    2714       constraint=constraint,
#    2715       variable_def=variable_def,
#    2716       import_scope=import_scope,
#    2717       distribute_strategy=distribute_strategy,
#    2718       synchronization=synchronization,
#    2719       aggregation=aggregation,
#    2720       shape=shape)
#    2721 else:
#    2722   return variables.RefVariable(
#    2723       initial_value=initial_value,
#    2724       trainable=trainable,
#    (...)
#    2735       aggregation=aggregation,
#    2736       shape=shape)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py:273, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     271   return cls._variable_v2_call(*args, **kwargs)
#     272 else:
# --> 273   return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1721, in ResourceVariable.__init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape, handle, experimental_enable_variable_lifting)
#    1716   self._init_from_handle(trainable=trainable,
#    1717                          shape=shape,
#    1718                          dtype=dtype,
#    1719                          handle=handle)
#    1720 else:
# -> 1721   self._init_from_args(
#    1722       initial_value=initial_value,
#    1723       trainable=trainable,
#    1724       collections=collections,
#    1725       caching_device=caching_device,
#    1726       name=name,
#    1727       dtype=dtype,
#    1728       constraint=constraint,
#    1729       synchronization=synchronization,
#    1730       aggregation=aggregation,
#    1731       shape=shape,
#    1732       distribute_strategy=distribute_strategy,
#    1733       validate_shape=validate_shape,
#    1734       experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#    1735       )
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1905, in ResourceVariable._init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape, validate_shape, experimental_enable_variable_lifting)
#    1903 with ops.name_scope("Initializer"), device_context_manager(None):
#    1904   if init_from_fn:
# -> 1905     initial_value = initial_value()
#    1906   if isinstance(initial_value, trackable.CheckpointInitialValue):
#    1907     self._maybe_initialize_trackable()
#
# File ~\anaconda3\lib\site-packages\keras\initializers\initializers_v2.py:637, in VarianceScaling.__call__(self, shape, dtype, **kwargs)
#     629     _ensure_keras_seeded()
#     630     return utils.call_with_layout(
#     631         self._generate_init_val,
#     632         layout,
#    (...)
#     635         nonce=nonce,
#     636     )
# --> 637 return self._generate_init_val(shape=shape, dtype=dtype, nonce=nonce)
#
# File ~\anaconda3\lib\site-packages\keras\initializers\initializers_v2.py:662, in VarianceScaling._generate_init_val(self, shape, dtype, nonce)
#     660 else:
#     661     limit = math.sqrt(3.0 * scale)
# --> 662     return self._random_generator.random_uniform(
#     663         shape, -limit, limit, dtype, nonce
#     664     )
#
# File ~\anaconda3\lib\site-packages\keras\backend.py:2100, in RandomGenerator.random_uniform(self, shape, minval, maxval, dtype, nonce)
#    2098     if nonce:
#    2099         seed = tf.random.experimental.stateless_fold_in(seed, nonce)
# -> 2100     return tf.random.stateless_uniform(
#    2101         shape=shape,
#    2102         minval=minval,
#    2103         maxval=maxval,
#    2104         dtype=dtype,
#    2105         seed=seed,
#    2106     )
#    2107 return tf.random.uniform(
#    2108     shape=shape,
#    2109     minval=minval,
#    (...)
#    2112     seed=self.make_legacy_seed(),
#    2113 )
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1176, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1174 # Fallback dispatch system (dispatch v1):
#    1175 try:
# -> 1176   return dispatch_target(*args, **kwargs)
#    1177 except (TypeError, ValueError):
#    1178   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1179   # TypeError, when given unexpected types.  So we need to catch both.
#    1180   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\stateless_random_ops.py:501, in stateless_random_uniform(shape, seed, minval, maxval, dtype, name, alg)
#     499   else:
#     500     key, counter, alg = _get_key_counter_alg(seed, alg)
# --> 501     rnd = gen_stateless_random_ops_v2.stateless_random_uniform_v2(
#     502         shape, key=key, counter=counter, dtype=dtype, alg=alg)
#     503     result = math_ops.add(rnd * (maxval - minval), minval, name=name)
#     504 tensor_util.maybe_set_static_shape(result, shape)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_stateless_random_ops_v2.py:483, in stateless_random_uniform_v2(shape, key, counter, alg, dtype, name)
#     481 if tld.is_eager:
#     482   try:
# --> 483     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     484       _ctx, "StatelessRandomUniformV2", name, shape, key, counter, alg,
#     485       "dtype", dtype)
#     486     return _result
#     487   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# 3. (3 points) Visualize the embedding projections for training and validation sets.

# %%
# Show Reconstructions
show_reconstructions(stacked_ae)

# %% [markdown]
# ---

# %% [markdown]
# # Problem 3 (15 points)
#
# In this problem, you will be working with the [California Housing dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_california_housing.html). The California Housing dataset consists of 20,640 samples, each described with 8 features. Let's import it:

# %%
from sklearn.datasets import fetch_california_housing 
housing = fetch_california_housing()
print(housing.DESCR)

# %%
X = housing.data # feature matrix (attributes/features are described above)

t = housing.target # target vector (median house value expressed in $100,000)

# %% [markdown]
# Answer the following questions:
#
# 1. (1 point) Partition the data into a *full training set* and a test set. Use a 80/20 stratified split with a fixed ```random_state```. Then partition the *full training set* into a train set and a validation set. For this last partition, use a 70/30 stratified split with a fixed ```random_state```.

# %%
from sklearn.model_selection import train_test_split
full_train, test = train_test_split(X, test_size=0.2, random_state=1)
train, validation = train_test_split(full_train, test_size=0.3, random_state=1)
print(full_train.shape)

# %% [markdown]
# 2. (1 point) Apply the standardization scaling to the train, validation and test sets. Use the train set to find the mean and standard deviation.

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

#train

scale= StandardScaler()

# separate the independent and dependent variables
X_data = train.data
t_train=train[:,0]
print(X_data)
#standardization of dependent variables
train_data = scale.fit_transform(X_data) 
#print(scaled_data)


#test

scale2= StandardScaler()

# separate the independent and dependent variables
X_data2 = test.data
t_test=test[:,0]

#standardization of dependent variables
test_data = scale.fit_transform(X_data2) 
#print(scaled_data)


#val

scale3= StandardScaler()

# separate the independent and dependent variables
X_data3 = validation.data
t_val=validation[:,0]

#standardization of dependent variables
val_data= scale.fit_transform(X_data3) 
#print(scaled_data)

#Mean and Std Dev
mean_train=np.mean(train_data)
std_dev_train=np.std(train_data)

print("Mean and standard deviation are ",mean_train," and ",std_dev_train )
train_data.shape
np.max(train_data)

# %% [markdown]
# 3. (5 points) Use the Sequential API to build an MLP with 2 hidden layers with the Leaky ReLU activation function and associated ```alpha=0.2```. The first hidden layer should have 50 neurons and the second 10 neurons. How many neurons should you include in the input and output layers? what should be the activation function in the output layer?

# %% [markdown]
# We are chossing the ipnut shape as (8,8) corresponding to the size of the feature columns, and the output shape is the highest target value (multi class classification. Since we are using a softmax activaion as this is a multiclass classification

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[8]),
    keras.layers.Dense(50, activation='LeakyReLU'),
    keras.layers.Dense(10, activation='LeakyReLU'),
    keras.layers.Dense(16, activation='softmax')
])

model.output_shape

# %%
model.summary()

# %% [markdown]
# 4. (3 points) Compile the model with the Mean Squared Error [loss function](https://keras.io/api/losses/), the Adam [optimizer](https://keras.io/api/optimizers/) with learning rate of 0.001, and the ```MeanSquaredError``` [performance metric](https://keras.io/api/metrics/).

# %%
from keras import metrics
loss_fn = keras.losses.SparseCategoricalCrossentropy()
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss=loss_fn, optimizer=opt)
model.compile(
    optimizer=opt,
    loss=loss_fn,
    metrics=[
        metrics.MeanSquaredError(name='my_mse'),
    ]
)

# %%
train_data.shape, t_train.shape, val_data.shape, t_val.shape

# %% [markdown]
# 5. (2 points) Train the model using the train and validation sets with online learning, 200 epochs and early stopping callback with a patience of 10 (on the loss value for the validation set). Plot the learning curves. Discuss your observations.

# %%
#callback = tf.keras.callbacks.EarlyStopping(monitor=loss_fn, patience=10)
history = model.fit(train_data, t_train, epochs=200, batch_size=32,
                    validation_data=(val_data, t_val))

# %%
history.history.keys()
history.params
key_names = list(history.history.keys())
colors = ['-r','--b','-og','-.k']

plt.figure(figsize=(8,5))
for i in range(len(key_names)):
    plt.plot(history.history[key_names[i]], colors[i], label=key_names[i])
plt.legend(fontsize=15,ncol=2)
plt.title('Learning Curves', size=15);

# %% [markdown]
# 6. (2 points) Evaluate the mean squared error performance in the train and test sets.

# %%
model.evaluate(test_data, t_test)

# %% [markdown]
# 7. (2 points) Predict the housing prices for the train and test sets. Use these predictions to calculate the [$r^2$ score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html).

# %%
X_new = test_data[:2]
X_new.shape
y_proba = model.predict(X_new)
y_proba.round(2)

# %% [markdown]
# ___

# %% [markdown]
# # Submit Your Solution
#
# Confirm that you've successfully completed the assignment.
#
# ```add``` and ```commit``` the final version of your work, and ```push``` your code to your GitHub repository.
#
# Submit the URL of your GitHub Repository as your assignment submission on Canvas.
